# %%
import pickle
import pandas as pd

# %%
from scripts.flattening.flatten_day_batch_pkl import run_batch_flatten
from utils.preprocessing.clean_flattened_df import clean_flattened_dataframe
from utils.preprocessing.add_embedding_indices import add_embedding_indices
from utils.preprocessing.process_text_fields import process_text_fields, extract_race_phrases
from utils.io.embedding_io import save_embeddings_npz
#from utils.io.save_model_ready_df import save_model_ready_pickle

# %% [raw]
# FIND ALL JSONS TO BATCH-PROCESS IN 'data/raw/' THEM FLATTEN AND MERGE THEM.

# %%
# Run flatten/merge module.
run_batch_flatten()
# Out:
# [INFO] 2025-03-28T04-59.json: 362 runners processed
#         Valid horse IDs: 360/362
#         class_num present: 277/362
# [INFO] 2025-03-26T08-58.json: 296 runners processed
#         Valid horse IDs: 295/296
#         class_num present: 163/296
# [INFO] 2025-03-30T04-57.json: 481 runners processed
#         Valid horse IDs: 476/481
#         class_num present: 228/481
# [INFO] 2025-03-27T07-37.json: 387 runners processed
#         Valid horse IDs: 383/387
#         class_num present: 256/387
# [INFO] 2025-03-31T04-51.json: 165 runners processed
#         Valid horse IDs: 165/165
#         class_num present: 165/165
# [INFO] 2025-03-29T04-58.json: 659 runners processed
#         Valid horse IDs: 653/659
#         class_num present: 561/659
# [SUCCESS] Flattened 2350 runners from 6 files
# [✓] CSV saved to data/processed/2025-04-02T09-30.csv
# [✓] Pickle saved to data/processed/2025-04-02T09-30.pkl

# %%
# Create a new datafrmae from the saved .pkl file.
new_df = pd.read_pickle('data/processed/2025-04-02T09-23.pkl')

# %%
# Analyse column attributes prior to cleaning
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 59 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   horse_id                 2350 non-null   object
#  1   horse_id_valid           2350 non-null   int64
#  2   course                   2350 non-null   object
#  3   country                  2350 non-null   object
#  4   going                    2350 non-null   object
#  5   GoingStick               0 non-null      object
#  6   distance_f               2350 non-null   float64
#  7   field_size               2350 non-null   int64
#  8   race_class               2350 non-null   object
#  9   class_num                1650 non-null   float64
#  10  class_label              1650 non-null   object
#  11  type                     2350 non-null   object
#  12  name                     2350 non-null   object
#  13  draw                     2158 non-null   float64
#  14  age                      2350 non-null   int64
#  15  sex                      2350 non-null   object
#  16  or                       1711 non-null   float64
#  17  rpr                      2042 non-null   float64
#  18  ts                       1471 non-null   float64
#  19  lbs                      2350 non-null   int64
#  20  headgear                 2350 non-null   object
#  21  last_run                 2350 non-null   object
#  22  form                     2350 non-null   object
#  23  trainer_id               2350 non-null   object
#  24  trainer_ovr_runs         2283 non-null   object
#  25  trainer_ovr_wins         2283 non-null   object
#  26  trainer_ovr_win_pct      2222 non-null   float64
#  27  trainer_ovr_profit       2283 non-null   float64
#  28  trainer_last_14_runs     2283 non-null   object
#  29  trainer_last_14_wins     2283 non-null   object
#  30  trainer_last_14_win_pct  2021 non-null   float64
#  31  trainer_last_14_profit   2283 non-null   float64
#  32  jockey_id                2350 non-null   object
#  33  jockey_ovr_runs          2283 non-null   object
#  34  jockey_ovr_wins          2283 non-null   object
#  35  jockey_ovr_win_pct       2222 non-null   float64
#  36  jockey_ovr_profit        2283 non-null   float64
#  37  jockey_last_14_runs      2283 non-null   object
#  38  jockey_last_14_wins      2283 non-null   object
#  39  jockey_last_14_win_pct   2126 non-null   float64
#  40  jockey_last_14_profit    2283 non-null   float64
#  41  comment                  2177 non-null   object
#  42  spotlight                2252 non-null   object
#  43  num_prev_trainers        2350 non-null   int64
#  44  num_prev_owners          2350 non-null   int64
#  45  rpr_rank                 2042 non-null   float64
#  46  or_rank                  1711 non-null   float64
#  47  rpr_zscore               2092 non-null   float64
#  48  or_zscore                2198 non-null   float64
#  49  race_id                  2350 non-null   int64
#  50  off_time                 2350 non-null   object
#  51  venue                    2350 non-null   object
#  52  race_datetime            2350 non-null   object
#  53  has_GoingStick           2350 non-null   int64
#  54  has_form                 2350 non-null   int64
#  55  has_comment              2350 non-null   int64
#  56  has_spotlight            2350 non-null   int64
#  57  has_headgear             2350 non-null   int64
#  58  non_runner_flag          2350 non-null   bool
# dtypes: bool(1), float64(18), int64(12), object(28)
# memory usage: 1.0+ MB

# %% [raw]
# CLEAN AND OPTIMIZE DATAFRAME

# %% [raw]
# Run to apply:
#
# Type conversions
# Datetime parsing
# Category encoding
# Dropping the useless GoingStick column

# %%
df_clean = clean_flattened_dataframe(new_df)
# Out:
# ✅ Filled NaNs in float columns: ['distance_f', 'class_num', 'draw', 'or', 'rpr', 'ts', 'trainer_ovr_runs', 'trainer_ovr_wins', 'trainer_ovr_win_pct', 'trainer_ovr_profit', 'trainer_last_14_runs', 'trainer_last_14_wins', 'trainer_last_14_win_pct', 'trainer_last_14_profit', 'jockey_ovr_runs', 'jockey_ovr_wins', 'jockey_ovr_win_pct', 'jockey_ovr_profit', 'jockey_last_14_runs', 'jockey_last_14_wins', 'jockey_last_14_win_pct', 'jockey_last_14_profit', 'rpr_rank', 'or_rank', 'rpr_zscore', 'or_zscore']

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 58 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   horse_id                 2350 non-null   object
#  1   horse_id_valid           2350 non-null   int64
#  2   course                   2350 non-null   object
#  3   country                  2350 non-null   category
#  4   going                    2350 non-null   category
#  5   distance_f               2350 non-null   float64
#  6   field_size               2350 non-null   int64
#  7   race_class               2350 non-null   category
#  8   class_num                2350 non-null   float64
#  9   class_label              1650 non-null   category
#  10  type                     2350 non-null   category
#  11  name                     2350 non-null   object
#  12  draw                     2350 non-null   float64
#  13  age                      2350 non-null   int64
#  14  sex                      2350 non-null   category
#  15  or                       2350 non-null   float64
#  16  rpr                      2350 non-null   float64
#  17  ts                       2350 non-null   float64
#  18  lbs                      2350 non-null   int64
#  19  headgear                 2350 non-null   category
#  20  last_run                 2350 non-null   object
#  21  form                     2350 non-null   object
#  22  trainer_id               2350 non-null   object
#  23  trainer_ovr_runs         2350 non-null   float64
#  24  trainer_ovr_wins         2350 non-null   float64
#  25  trainer_ovr_win_pct      2350 non-null   float64
#  26  trainer_ovr_profit       2350 non-null   float64
#  27  trainer_last_14_runs     2350 non-null   float64
#  28  trainer_last_14_wins     2350 non-null   float64
#  29  trainer_last_14_win_pct  2350 non-null   float64
#  30  trainer_last_14_profit   2350 non-null   float64
#  31  jockey_id                2350 non-null   object
#  32  jockey_ovr_runs          2350 non-null   float64
#  33  jockey_ovr_wins          2350 non-null   float64
#  34  jockey_ovr_win_pct       2350 non-null   float64
#  35  jockey_ovr_profit        2350 non-null   float64
#  36  jockey_last_14_runs      2350 non-null   float64
#  37  jockey_last_14_wins      2350 non-null   float64
#  38  jockey_last_14_win_pct   2350 non-null   float64
#  39  jockey_last_14_profit    2350 non-null   float64
#  40  comment                  2177 non-null   object
#  41  spotlight                2252 non-null   object
#  42  num_prev_trainers        2350 non-null   int64
#  43  num_prev_owners          2350 non-null   int64
#  44  rpr_rank                 2350 non-null   float64
#  45  or_rank                  2350 non-null   float64
#  46  rpr_zscore               2350 non-null   float64
#  47  or_zscore                2350 non-null   float64
#  48  race_id                  2350 non-null   int64
#  49  off_time                 2350 non-null   object
#  50  venue                    2350 non-null   category
#  51  race_datetime            2350 non-null   datetime64[ns]
#  52  has_GoingStick           2350 non-null   int64
#  53  has_form                 2350 non-null   int64
#  54  has_comment              2350 non-null   int64
#  55  has_spotlight            2350 non-null   int64
#  56  has_headgear             2350 non-null   int64
#  57  non_runner_flag          2350 non-null   bool
# dtypes: bool(1), category(8), datetime64[ns](1), float64(26), int64(12), object(10)
# memory usage: 924.0+ KB

# %% [raw]
# We now have:
#
# - Optimized category types for embeddings
# - race_datetime as datetime64[ns]
# - Clean float/int structure
# - Useless GoingStick removed
# - Flags like has_GoingStick intact in case we reintroduce 'Goingstick' later

# %% [raw]
# ADD EMBEDDING INDICES.

# %% [raw]
# We'll convert categorical fields into *_idx integer columns using LabelEncoder, for transformer ingestion.  This will:
#
# - Label encode key categorical fields (country, going, sex, etc.)
# - Add *_idx columns for transformer embedding layers
# - Return a dictionary of LabelEncoder objects (encoders) you can save or inspect

# %%
df_indexed, encoders = add_embedding_indices(df_clean)

# %%
# This will give you a preview of the new integer columns like:
# country_idx, going_idx, venue_idx, etc.
df_indexed.filter(like='_idx').head()
# Out:
#    country_idx  going_idx  sex_idx  type_idx  class_label_idx  headgear_idx  \
# 0            4          6        2         1                1            12
# 1            4          6        2         1                1             0
# 2            4          6        2         1                1            17
# 3            4          6        2         1                1             0
# 4            4          6        1         1                1             4
#
#    race_class_idx  venue_idx
# 0               0          7
# 1               0          7
# 2               0          7
# 3               0          7
# 4               0          7

# %%
df_indexed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 66 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   horse_id                 2350 non-null   object
#  1   horse_id_valid           2350 non-null   int64
#  2   course                   2350 non-null   object
#  3   country                  2350 non-null   category
#  4   going                    2350 non-null   category
#  5   distance_f               2350 non-null   float64
#  6   field_size               2350 non-null   int64
#  7   race_class               2350 non-null   category
#  8   class_num                2350 non-null   float64
#  9   class_label              1650 non-null   category
#  10  type                     2350 non-null   category
#  11  name                     2350 non-null   object
#  12  draw                     2350 non-null   float64
#  13  age                      2350 non-null   int64
#  14  sex                      2350 non-null   category
#  15  or                       2350 non-null   float64
#  16  rpr                      2350 non-null   float64
#  17  ts                       2350 non-null   float64
#  18  lbs                      2350 non-null   int64
#  19  headgear                 2350 non-null   category
#  20  last_run                 2350 non-null   object
#  21  form                     2350 non-null   object
#  22  trainer_id               2350 non-null   object
#  23  trainer_ovr_runs         2350 non-null   float64
#  24  trainer_ovr_wins         2350 non-null   float64
#  25  trainer_ovr_win_pct      2350 non-null   float64
#  26  trainer_ovr_profit       2350 non-null   float64
#  27  trainer_last_14_runs     2350 non-null   float64
#  28  trainer_last_14_wins     2350 non-null   float64
#  29  trainer_last_14_win_pct  2350 non-null   float64
#  30  trainer_last_14_profit   2350 non-null   float64
#  31  jockey_id                2350 non-null   object
#  32  jockey_ovr_runs          2350 non-null   float64
#  33  jockey_ovr_wins          2350 non-null   float64
#  34  jockey_ovr_win_pct       2350 non-null   float64
#  35  jockey_ovr_profit        2350 non-null   float64
#  36  jockey_last_14_runs      2350 non-null   float64
#  37  jockey_last_14_wins      2350 non-null   float64
#  38  jockey_last_14_win_pct   2350 non-null   float64
#  39  jockey_last_14_profit    2350 non-null   float64
#  40  comment                  2177 non-null   object
#  41  spotlight                2252 non-null   object
#  42  num_prev_trainers        2350 non-null   int64
#  43  num_prev_owners          2350 non-null   int64
#  44  rpr_rank                 2350 non-null   float64
#  45  or_rank                  2350 non-null   float64
#  46  rpr_zscore               2350 non-null   float64
#  47  or_zscore                2350 non-null   float64
#  48  race_id                  2350 non-null   int64
#  49  off_time                 2350 non-null   object
#  50  venue                    2350 non-null   category
#  51  race_datetime            2350 non-null   datetime64[ns]
#  52  has_GoingStick           2350 non-null   int64
#  53  has_form                 2350 non-null   int64
#  54  has_comment              2350 non-null   int64
#  55  has_spotlight            2350 non-null   int64
#  56  has_headgear             2350 non-null   int64
#  57  non_runner_flag          2350 non-null   bool
#  58  country_idx              2350 non-null   int64
#  59  going_idx                2350 non-null   int64
#  60  sex_idx                  2350 non-null   int64
#  61  type_idx                 2350 non-null   int64
#  62  class_label_idx          2350 non-null   int64
#  63  headgear_idx             2350 non-null   int64
#  64  race_class_idx           2350 non-null   int64
#  65  venue_idx                2350 non-null   int64
# dtypes: bool(1), category(8), datetime64[ns](1), float64(26), int64(20), object(10)
# memory usage: 1.0+ MB

# %%
encoders
# Out:
# {'country': LabelEncoder(),
#  'going': LabelEncoder(),
#  'sex': LabelEncoder(),
#  'type': LabelEncoder(),
#  'class_label': LabelEncoder(),
#  'headgear': LabelEncoder(),
#  'race_class': LabelEncoder(),
#  'venue': LabelEncoder()}

# %%
# Save encoders
import joblib
joblib.dump(encoders, 'data/processed/embedding_encoders_march-2025.pkl')
# Out:
# ['data/processed/embedding_encoders_march-2025.pkl']

# %% [raw]
# NLP EMBEDDING + REGEX STEP

# %% [raw]
# We'll get:
#
# - comment_vector, spotlight_vector as np.array-per-row
# - 30+ binary NLP features (e.g., mentions_ground_form_comment)
# - embeddings_dict: raw numpy blocks ((1704, 384) each)
# - regex_features: the list of all new NLP flag columns

# %%
df_nlp, embeddings_dict, regex_features = process_text_fields(
    df_indexed,
    fields=["comment", "spotlight"],
    enable_regex=True
)
# Out:
# Embedding field: comment
# Batches:   0%|          | 0/74 [00:00<?, ?it/s]
# Embedding field: spotlight
# Batches:   0%|          | 0/74 [00:00<?, ?it/s]

# %%
df_nlp.info(all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 102 columns):
#  #    Column                                    Dtype
# ---   ------                                    -----
#  0    horse_id                                  object
#  1    horse_id_valid                            int64
#  2    course                                    object
#  3    country                                   category
#  4    going                                     category
#  5    distance_f                                float64
#  6    field_size                                int64
#  7    race_class                                category
#  8    class_num                                 float64
#  9    class_label                               category
#  10   type                                      category
#  11   name                                      object
#  12   draw                                      float64
#  13   age                                       int64
#  14   sex                                       category
#  15   or                                        float64
#  16   rpr                                       float64
#  17   ts                                        float64
#  18   lbs                                       int64
#  19   headgear                                  category
#  20   last_run                                  object
#  21   form                                      object
#  22   trainer_id                                object
#  23   trainer_ovr_runs                          float64
#  24   trainer_ovr_wins                          float64
#  25   trainer_ovr_win_pct                       float64
#  26   trainer_ovr_profit                        float64
#  27   trainer_last_14_runs                      float64
#  28   trainer_last_14_wins                      float64
#  29   trainer_last_14_win_pct                   float64
#  30   trainer_last_14_profit                    float64
#  31   jockey_id                                 object
#  32   jockey_ovr_runs                           float64
#  33   jockey_ovr_wins                           float64
#  34   jockey_ovr_win_pct                        float64
#  35   jockey_ovr_profit                         float64
#  36   jockey_last_14_runs                       float64
#  37   jockey_last_14_wins                       float64
#  38   jockey_last_14_win_pct                    float64
#  39   jockey_last_14_profit                     float64
#  40   comment                                   object
#  41   spotlight                                 object
#  42   num_prev_trainers                         int64
#  43   num_prev_owners                           int64
#  44   rpr_rank                                  float64
#  45   or_rank                                   float64
#  46   rpr_zscore                                float64
#  47   or_zscore                                 float64
#  48   race_id                                   int64
#  49   off_time                                  object
#  50   venue                                     category
#  51   race_datetime                             datetime64[ns]
#  52   has_GoingStick                            int64
#  53   has_form                                  int64
#  54   has_comment                               int64
#  55   has_spotlight                             int64
#  56   has_headgear                              int64
#  57   non_runner_flag                           bool
#  58   country_idx                               int64
#  59   going_idx                                 int64
#  60   sex_idx                                   int64
#  61   type_idx                                  int64
#  62   class_label_idx                           int64
#  63   headgear_idx                              int64
#  64   race_class_idx                            int64
#  65   venue_idx                                 int64
#  66   comment_vector                            object
#  67   spotlight_vector                          object
#  68   mentions_course_win_comment               int64
#  69   mentions_course_win_spotlight             int64
#  70   mentions_trip_change_comment              int64
#  71   mentions_trip_change_spotlight            int64
#  72   mentions_surface_comment                  int64
#  73   mentions_surface_spotlight                int64
#  74   mentions_front_runner_comment             int64
#  75   mentions_front_runner_spotlight           int64
#  76   mentions_layoff_comment                   int64
#  77   mentions_layoff_spotlight                 int64
#  78   mentions_first_time_headgear_comment      int64
#  79   mentions_first_time_headgear_spotlight    int64
#  80   mentions_class_drop_comment               int64
#  81   mentions_class_drop_spotlight             int64
#  82   mentions_class_rise_comment               int64
#  83   mentions_class_rise_spotlight             int64
#  84   mentions_course_form_comment              int64
#  85   mentions_course_form_spotlight            int64
#  86   mentions_distance_form_comment            int64
#  87   mentions_distance_form_spotlight          int64
#  88   mentions_ground_form_comment              int64
#  89   mentions_ground_form_spotlight            int64
#  90   mentions_classy_rival_comment             int64
#  91   mentions_classy_rival_spotlight           int64
#  92   mentions_fitness_query_comment            int64
#  93   mentions_fitness_query_spotlight          int64
#  94   mentions_positive_trainer_note_comment    int64
#  95   mentions_positive_trainer_note_spotlight  int64
#  96   mentions_jockey_combo_comment             int64
#  97   mentions_jockey_combo_spotlight           int64
#  98   mentions_improver_flag_comment            int64
#  99   mentions_improver_flag_spotlight          int64
#  100  mentions_loser_flag_comment               int64
#  101  mentions_loser_flag_spotlight             int64
# dtypes: bool(1), category(8), datetime64[ns](1), float64(26), int64(54), object(12)
# memory usage: 1.7+ MB

# %%
# Save the embeddings.
save_embeddings_npz(
    embeddings_dict,
    'data/processed/text_embeddings_march-2025.npz'
)
# Out:
# [✓] Saved 2 embedding blocks to data/processed/text_embeddings_march-2025.npz

# %%
# To load embeddings later.
from utils.embedding_io import load_embeddings_npz
# Optional; validate shape.
expected = {"comment": (1704, 384), "spotlight": (1704, 384)}
embeddings = load_embeddings_npz(
    "data/processed/text_embeddings_2025-03-31.npz",
    expected_schema=expected
)
# Out:
# [✓] Loaded 2 embedding blocks from data/processed/text_embeddings_2025-03-31.npz
# [✓] Schema validation passed.

# %%
df_nlp.head(10)
# Out:
#   horse_id  ...  mentions_loser_flag_spotlight
# 0  3679956  ...                              0
# 1  5148102  ...                              0
# 2  2455830  ...                              0
# 3  5301548  ...                              0
# 4  5021592  ...                              0
# 5  5329156  ...                              0
# 6  3279638  ...                              0
# 7  2645561  ...                              0
# 8  4274148  ...                              0
# 9  5237784  ...                              0
#
# [10 rows x 102 columns]

# %% [raw]
# SAVE PICKLE FILE OF MODEL-READY DATASET + .CSV FOR CHATGPT.

# %%
df_nlp.to_pickle("data/processed/model_ready_march-2025.pkl")
df_nlp.to_csv("data/processed/model_ready_march-2025.csv", index=False)

# %% [raw]
# MISCELLANEOUS VALIDATION

# %%
# We have had issues with trainer/jockey stats not populating correctly.
trainer_cols = [col for col in df_nlp.columns if col.startswith("trainer_")]
jockey_cols = [col for col in df_nlp.columns if col.startswith("jockey_")]

df_nlp[trainer_cols + jockey_cols].isna().sum()
# Out:
# trainer_id                   0
# trainer_ovr_runs            67
# trainer_ovr_wins            67
# trainer_ovr_win_pct        128
# trainer_ovr_profit          67
# trainer_last_14_runs        67
# trainer_last_14_wins        67
# trainer_last_14_win_pct    329
# trainer_last_14_profit      67
# jockey_id                    0
# jockey_ovr_runs             67
# jockey_ovr_wins             67
# jockey_ovr_win_pct         128
# jockey_ovr_profit           67
# jockey_last_14_runs         67
# jockey_last_14_wins         67
# jockey_last_14_win_pct     224
# jockey_last_14_profit       67
# dtype: int64

# %%
# We to a sanity check to see if both these below return zero.
trainer_issues = df_nlp[
    (df_nlp['trainer_ovr_runs'] > 0) &
    (df_nlp['trainer_ovr_win_pct'].isna())
]
print(f"Trainer win % missing despite having runs: {len(trainer_issues)}")

jockey_issues = df_nlp[
    (df_nlp['jockey_ovr_runs'] > 0) &
    (df_nlp['jockey_ovr_win_pct'].isna())
]
print(f"Jockey win % missing despite having runs: {len(jockey_issues)}")
# Out:
# Trainer win % missing despite having runs: 0
# Jockey win % missing despite having runs: 0
